# %%
import random

print(' WELCOME TO PASSWORD GENERATOR ')

chars = 'qazwsxedcrfvtgbyhnujmikolpQAZWSXEDCRFVTGBYHNUJIKOLP1234567890@#&'

number = input('HOW MANY PASSWORD TO BE GENERATED:')
number = int(number)

lenght = input('AMOUNT OF LENGHT OF YOUR PASSWORD:')
lenght = int(lenght)

print('HEY,GRAB YOUR PASSWORDS:')


for pwd in range(number):
  passwords=''
  for c in range(lenght):
    passwords +=random.choice(chars)
  print(passwords)
# Out:
#  WELCOME TO PASSWORD GENERATOR
# HOW MANY PASSWORD TO BE GENERATED:8
# AMOUNT OF LENGHT OF YOUR PASSWORD:8
# HEY,GRAB YOUR PASSWORDS:
# lWNE8Sdz
# FubEy&ci
# rUVy7CKF
# TGKjezI3
# ie7ApIOK
# jAAQn1ug
# DukxB@Qh
# sykO4LGV
