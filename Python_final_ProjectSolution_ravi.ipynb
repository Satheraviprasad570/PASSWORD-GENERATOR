# %% [markdown]
# <a href="https://colab.research.google.com/github/Satheraviprasad570/PASSWORD-GENERATOR/blob/main/Python_final_ProjectSolution_ravi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-2bfe8f43-e41a-47d7-8152-c566575294eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bfe8f43-e41a-47d7-8152-c566575294eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving customers.csv to customers (1).csv

# %%
import pandas as pd

# %%
from google.colab import files
data2 = files.upload()
# Out:
#      <input type="file" id="files-a3188c77-fbc3-4236-86cb-f25f1e99a85e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3188c77-fbc3-4236-86cb-f25f1e99a85e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving products.csv to products.csv

# %%
from google.colab import files
data3 = files.upload()
# Out:
#      <input type="file" id="files-7e9192a1-103b-4e77-83a9-87038364166d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e9192a1-103b-4e77-83a9-87038364166d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving transactions.csv to transactions.csv

# %%
#headers for each dataframe 
mycustomers_list = ['custno','firstname','lastname','gender','age','profession','contactNo',
'emailId','city','state','isActive','createdDate','UpdatedDate']
products_list=['productno','productName','Description','isActive','createdDate','UpdatedDate']
transactions_header = ['txnno', 'txndate','custno', 'amount','productno', 'spendby']

# %%
#dataframe creation and applying header for it 
customers_ = pd.read_csv('customers (1).csv',names=mycustomers_list)
products_ = pd.read_csv('products.csv',names=products_list)
transactions_ = pd.read_csv('transactions.csv',names=transactions_header)

# %%
#usecase no 1
customers_.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive          createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#            UpdatedDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# 3  2017-10-18 12:12:28
# 4  2017-10-18 12:12:28

# %%
#usecase no 1
products_.head()
# Out:
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
#usecase no 1
transactions_.head()
# Out:
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %%
#usecase no 02 here is i am unable to fetch only those customers but i got the bool value of all of it 
usecases_2 = transactions_.groupby('custno').count()
usecases_2
counted = usecases_2>=4
usecases_2.loc[(usecases_2['productno'] >= 4)]
#ed
# Out:
#         txnno  txndate  amount  productno  spendby
# custno
# 4           4        4       4          4        4
# 86          4        4       4          4        4
# 167         4        4       4          4        4
# 187         4        4       4          4        4
# 237         4        4       4          4        4
# 241         5        5       5          5        5
# 321         4        4       4          4        4
# 326         4        4       4          4        4
# 331         4        4       4          4        4
# 356         4        4       4          4        4
# 391         5        5       5          5        5
# 537         4        4       4          4        4
# 558         4        4       4          4        4
# 578         4        4       4          4        4
# 709         4        4       4          4        4
# 735         4        4       4          4        4
# 753         4        4       4          4        4
# 828         4        4       4          4        4
# 989         4        4       4          4        4

# %%
#usecase no 02  i did it with diffrent logic for only those customers who purchased more than 3 products 
#here 2nd column is actully count of purchase
from numpy.ma.core import count
usecases_2 = transactions_.groupby('custno').agg({'custno':'count'})
df2 = usecases_2.loc[(usecases_2['custno'] >= 4)]
df2
# Out:
#         custno
# custno
# 4            4
# 86           4
# 167          4
# 187          4
# 237          4
# 241          5
# 321          4
# 326          4
# 331          4
# 356          4
# 391          5
# 537          4
# 558          4
# 578          4
# 709          4
# 735          4
# 753          4
# 828          4
# 989          4

# %%
#usecase no 3
usecases_3 = transactions_.groupby('productno').count()
counted = usecases_3.sort_values(by = 'custno', ascending =False)
#counted.head()
counted.head()
# Out:
#            txnno  txndate  custno  amount  spendby
# productno
# 82             5        5       5       5        5
# 768            5        5       5       5        5
# 900            5        5       5       5        5
# 427            5        5       5       5        5
# 233            4        4       4       4        4

# %%
#usecase no 4
usecases_4 = transactions_.groupby('amount').count()
counted = usecases_4.sort_values(by ='custno', ascending =False)
counted.head()
# Out:
#         txnno  txndate  custno  productno  spendby
# amount
# 2822        3        3       3          3        3
# 3466        3        3       3          3        3
# 3181        3        3       3          3        3
# 2364        2        2       2          2        2
# 3423        2        2       2          2        2

# %%
#usecase no 5
usecases_5 =customers_['profession'].unique()
print('unique professions of customers are ...', usecases_5)
print('total unique professions of cutomers are ', len(usecases_5))
# Out:
# unique professions of customers are ... ['B' 'S']
# total unique professions of cutomers are  2

# %%
#usecase no 6
high_age=customers_['age'].max()
print("highest age amoung the customer's database is ",high_age)
# Out:
# highest age amoung the customer's database is  64

# %%
customer_df1 = customers_[['custno','gender','age','profession','contactNo',]]
product_df1 =products_[['productno','productName']]
transactions_df1=transactions_[['txndate','spendby','amount']]

# %%
# usecase no 07
x = pd.concat([customer_df1,product_df1,transactions_df1],axis =1)
x.set_index('custno',inplace =True)
x.iloc[int(input('enter customer number '))-1]
# Out:
# enter customer number 923
# gender                           F
# age                             46
# profession                       B
# contactNo                    25436
# productno                      923
# productName             Product923
# txndate        2017-10-18 12:31:46
# spendby                       Card
# amount                        1948
# Name: 923, dtype: object

# %%
from google.colab import files
psv = files.upload()
# Out:
#      <input type="file" id="files-85bcf025-61ca-4c76-a0c6-1cb70d103706" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85bcf025-61ca-4c76-a0c6-1cb70d103706">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving customers.txt to customers.txt

# %%
#usecase 08
psv_customers_df = pd.read_csv('customers.txt',sep='|',names=mycustomers_list)
psv_customers_df.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive          createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#            UpdatedDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# 3  2017-10-18 12:12:28
# 4  2017-10-18 12:12:28

# %%
from google.colab import files
psv2 = files.upload()
# Out:
#      <input type="file" id="files-594773b6-457b-49f2-bb82-c5e82b9c5b96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-594773b6-457b-49f2-bb82-c5e82b9c5b96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving products.txt to products.txt

# %%
#usecase 08
psv_products_df = pd.read_csv('products.txt',sep = '|',names=products_list)
psv_products_df.head()
# Out:
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
from google.colab import files
psv3 = files.upload()
# Out:
#      <input type="file" id="files-199eb0a1-d7ec-4a37-aa34-c37f102ff234" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-199eb0a1-d7ec-4a37-aa34-c37f102ff234">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving transactions.txt to transactions.txt

# %%
#usecase 08
psv_transactions_df = pd.read_csv('transactions.txt',sep='|',names=transactions_header)
psv_transactions_df.head()
# Out:
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %%
from google.colab import files
json1 =files.upload()
# Out:
#      <input type="file" id="files-bf7c64c3-3435-42cd-9425-a8a71bc01f5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf7c64c3-3435-42cd-9425-a8a71bc01f5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving products.json to products.json

# %%
#usecase no 09
df_products_json = pd.read_json('products.json',lines= True)
df_products_json.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1        101          Toyota         six         2  2017-10-03  2017-11-13
# 2        102  General Motors         two         1  2017-09-18  2017-11-03
# 3        103         Renault       eight         2  2017-10-05  2017-11-13
# 4        104        Kenworth       three         1  2017-05-03  2017-11-04

# %%
from google.colab import files
json2 =files.upload()
# Out:
#      <input type="file" id="files-75a12763-b495-415a-abbf-475ed8c4b3ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75a12763-b495-415a-abbf-475ed8c4b3ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving customers.json to customers (2).json

# %%
#usecase no 09
df_customers_json = pd.read_json('customers (2).json',lines=True)
df_customers_json.head()
# Out:
#    custno  firstname lastname  gender  age          profession      contactNo  \
# 0       1        Dai    Noble       2   53     Human Resources  1644101928099
# 1       2        Kay     Wise       2   26    Public Relations  1674031917099
# 2       3       Amir     Pace       1   43  Customer Relations  1636050509999
# 3       4  Sebastian    Lopez       2   32  Customer Relations  1666010108899
# 4       5      Brian   Maddox       1   40   Quality Assurance  1646080399299
#
#                         emailId             city       state  isActive  \
# 0  eu.lacus.Quisque@loremac.com           Berlin      Berlin         1
# 1          ridiculus@Sednunc.ca        Oldenzaal  Overijssel         2
# 2    quam.Pellentesque@erat.edu          Cobourg     Ontario         2
# 3           magna@venenatis.net       Te Awamutu          NI         1
# 4         ac.facilisis@Duis.com  Greater Sudbury     Ontario         2
#
#   createdDate UpdatedDate
# 0  2017-03-01  2018-08-25
# 1  2017-04-10  2018-08-30
# 2  2017-03-04  2018-09-18
# 3  2016-12-17  2018-09-12
# 4  2017-02-18  2018-05-13

# %%
from google.colab import files
json3 =files.upload()
# Out:
#      <input type="file" id="files-7fd95c94-8027-4154-adf0-e4be2f4794d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fd95c94-8027-4154-adf0-e4be2f4794d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving transactions.json to transactions.json

# %%
#usecase no 9
df_transactions_json = pd.read_json('transactions.json',lines = True)
df_transactions_json.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-07-31      71     181         19        2
# 1      2  2017-04-02      44     401         48        2
# 2      3  2018-01-31      45    1808         44        2
# 3      4  2018-04-02      62      65         22        2
# 4      5  2017-08-17      88    1149         74        2

# %%
from google.colab import files
xml1 =files.upload()
# Out:
#      <input type="file" id="files-569073ee-a6ae-4443-90f1-9064b75c7196" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-569073ee-a6ae-4443-90f1-9064b75c7196">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving customers.xml to customers.xml

# %%
#usecase no 10
df_customers_xml = pd.read_xml('customers.xml')
df_customers_xml.head()
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
#   createdDate UpdatedDate
# 0  2016-12-07  2018-09-05
# 1  2017-04-26  2018-06-04
# 2  2017-01-02  2018-08-01
# 3  2017-02-11  2018-07-18
# 4  2017-03-30  2018-05-19

# %%
from google.colab import files
xml2 =files.upload()
# Out:
#      <input type="file" id="files-e7b39fb5-5ab2-44c2-83f8-6b99ea4a6b0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7b39fb5-5ab2-44c2-83f8-6b99ea4a6b0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving products.xml to products.xml

# %%
#usecase no 10
df_products_xml = pd.read_xml('products.xml')
df_products_xml.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1        101           Honda       eight         1  2017-04-10  2017-11-11
# 2        102             GMC       three         2  2017-02-09  2017-11-17
# 3        103           Lexus       eight         2  2017-06-01  2017-11-04
# 4        104           Smart        five         2  2017-08-10  2017-11-16

# %%
from google.colab import files
xml3 =files.upload()
# Out:
#      <input type="file" id="files-8b1a3f28-0541-4af8-a45c-07bce14098c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b1a3f28-0541-4af8-a45c-07bce14098c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving transactions.xml to transactions.xml

# %%
#usecase no 10
df_transactions_xml = pd.read_xml('transactions.xml')
df_transactions_xml.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-09-16       6     576         73        1
# 1      2  2018-02-11      96    1038         40        2
# 2      3  2017-06-13      17     673          2        1
# 3      4  2017-07-25      89    1284        100        2
# 4      5  2017-06-15       9    1685         56        2
